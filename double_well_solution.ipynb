# %% [markdown]
# # Solução/Raízes das Equações Transcendentais

# %% [markdown]
# ## 1 Energias abaixo da barreira de potencial

# %%
#libraries

import numpy as np
from scipy import optimize
from scipy.optimize import fsolve
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# Parametros

h_bar = 1
m = 1
V_0 = 50
a = 0.5
L = 1

# %% [markdown]
# #### 1.1 E < V_0

# %%
# Equação #1 de Energia 

def func_1(E_1):
    k = np.sqrt(2 * m * E_1) / h_bar # k (região V_0 = 0)
    B = np.sqrt(2 * m * (V_0 - E_1)) / h_bar # B (região V_0 != 0)
    eq1 = k * (1 / np.tan(k * a)) + B * np.tanh(B / 2 * (L - a)) # primeira equação transcendental (red)
    return eq1

raizes1 = fsolve(func_1, [10,40]) #rotina scipy, 'chutando' um range de vizinhos próximos das interseções
solucao1 = print(raizes1)

# Gráfico das raízes 

E_1 = np.linspace(0,50,1000)
plt.plot(E_1,func_1(E_1),lw=1)
plt.plot(raizes1,func_1(raizes1),'s',ms=10,color='blue')
plt.axhline(0,color='gray',lw=0.5)
plt.ylim([-15,150])
plt.xlim([0,50])
plt.xlabel('Valores para Energia')
plt.title('Raízes Possíveis')
plt.show()
# Out:
# [13.37208438 47.01861504]
# /home/paulo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in true_divide
#
# /home/paulo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in multiply

# %%
# Equação #2 de Energia 

def func_2(E_2):
    k = np.sqrt(2 * m * E_2) / h_bar # k (região V_0 = 0)
    B = np.sqrt(2 * m * (V_0 - E_2)) / h_bar # B (região V_0 != 0)
    eq2 = k * (1 / np.tan(k * a)) +  B * (1 / np.tanh(B / 2 * (L - a))) # segunda equação transcendental (green)
    return eq2

raizes2 = fsolve(func_2, 10) #rotina scipy, 'chutando' vizinhos próximos da interseção
solucao2 = print(raizes2)

# Gráfico das Soluções
E_2 = np.linspace(-500,500,100000)
plt.plot(E_2,func_2(E_2),lw=1)
plt.plot(raizes2,func_2(raizes2),'s',ms=10,color='blue')
plt.axhline(0,color='gray',lw=0.5)
plt.ylim([-15,150])
plt.xlabel('Valores para Energia')
plt.title('Raízes Possíveis')
plt.show()
# Out:
# [13.5801715]
# /home/paulo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in sqrt
#   after removing the cwd from sys.path.

# %% [markdown]
# ## 2 Energias acima da barreira de potencial
#
# #### 2.1 E > V_0

# %%
# Equação #3 de Energia
def func_3(E_3):
    k = np.sqrt(2 * m * E_3) / h_bar # k (região V_0 = 0)
    B = np.sqrt(2 * m * (E_3 - V_0)) / h_bar # B (região E > V_0 !!!)
    eq3 = k * (1 / np.tan(k * a)) -  B * np.tan(B / 2 * (L - a)) # primeira equação transcendental (red)
    return eq3

raizes3 = fsolve(func_3,list(range(70,800))) #rotina scipy, 'chutando' vizinhos próximos da interseção
#solucao3 = print(raizes3)

# Gráfico das Soluções
E_3 = np.linspace(0,800,100)
plt.plot(E_3,func_3(E_3),lw=1)
plt.plot(raizes3,func_3(raizes3),'s',ms=10, color='blue')
plt.axhline(0,color='gray',lw=0.5)
plt.ylim([-30,100])
plt.xlim([50,700])
plt.xlabel('Valores para Energia')
plt.title('Raízes Possíveis')
plt.show()
# Out:
# /home/paulo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/paulo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in sqrt
#   after removing the cwd from sys.path.
# /home/paulo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# /home/paulo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in multiply
#   """

# %%
# Equação #4 de Energia
def func_4(E_4):
    k = np.sqrt(2 * m * E_4) / h_bar # k (região V_0 = 0)
    B = np.sqrt(2 * m * (E_4 - V_0)) / h_bar # B (região E > V_0 !!!)
    eq4 = -k * (1 / np.tan(k * a)) -  B * (1 / np.tan(B / 2 * (L - a))) # segunda equação transcendental E > V_0 (green)
    return eq4

raizes4 = fsolve(func_4,list(range(121,250))) #rotina scipy, 'chutando' vizinhos próximos da interseção
raizes4_1 = fsolve(func_4,list(range(250,800)))
#solucao4 = print(raizes4)
#solucao4 = print(raizes4_1)

# Gráfico das Soluções
E_4 = np.linspace(0,800,1000)
plt.plot(E_4,func_4(E_4),lw=1)
plt.plot(raizes4,func_4(raizes4),'s',ms=10,color='blue')
plt.plot(raizes4_1,func_4(raizes4_1),'s',ms=10,color='blue')
plt.axhline(0,color='gray',lw=0.5)
plt.ylim([-10,150])
plt.xlim([50,800])
plt.xlabel('Valores para Energia')
plt.title('Raízes Possíveis')
plt.show()
# Out:
# /home/paulo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in sqrt
#   after removing the cwd from sys.path.
# /home/paulo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/paulo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# /home/paulo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in multiply
#   """
